# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/long/OneDrive/Desktop/who_suicide_statistics.csv')

# %%
data.head(10)
# Out:
#    country  year     sex          age  suicides_no  population
# 0  Albania  1985  female  15-24 years          NaN    277900.0
# 1  Albania  1985  female  25-34 years          NaN    246800.0
# 2  Albania  1985  female  35-54 years          NaN    267500.0
# 3  Albania  1985  female   5-14 years          NaN    298300.0
# 4  Albania  1985  female  55-74 years          NaN    138700.0
# 5  Albania  1985  female    75+ years          NaN     34200.0
# 6  Albania  1985    male  15-24 years          NaN    301400.0
# 7  Albania  1985    male  25-34 years          NaN    264200.0
# 8  Albania  1985    male  35-54 years          NaN    296700.0
# 9  Albania  1985    male   5-14 years          NaN    325800.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43776 entries, 0 to 43775
# Data columns (total 6 columns):
# country        43776 non-null object
# year           43776 non-null int64
# sex            43776 non-null object
# age            43776 non-null object
# suicides_no    41520 non-null float64
# population     38316 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.0+ MB

# %%
data['suicides_no'].unique()
# Out:
# array([       nan, 1.4000e+01, 4.0000e+00, ..., 1.1634e+04, 9.0680e+03,
#        3.1710e+03])

# %%
data['country'].unique()
# Out:
# array(['Albania', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bermuda', 'Bolivia', 'Bosnia and Herzegovina', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Cabo Verde', 'Canada', 'Cayman Islands', 'Chile', 'Colombia',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Estonia', 'Falkland Islands (Malvinas)', 'Fiji',
#        'Finland', 'France', 'French Guiana', 'Georgia', 'Germany',
#        'Greece', 'Grenada', 'Guadeloupe', 'Guatemala', 'Guyana', 'Haiti',
#        'Honduras', 'Hong Kong SAR', 'Hungary', 'Iceland',
#        'Iran (Islamic Rep of)', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kiribati', 'Kuwait',
# ...

# %%
data['age'].unique()
# Out:
# array(['15-24 years', '25-34 years', '35-54 years', '5-14 years',
#        '55-74 years', '75+ years'], dtype=object)

# %%
data['year'].unique()
# Out:
# array([1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 1983, 1984,
#        2016, 1979, 1980, 1981, 1982], dtype=int64)

# %%
data['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['suicides_no']=data['suicides_no'].fillna('0')
data['population']=data['population'].fillna('0')

# %%
data.head(20)
# Out:
#     country  year     sex          age suicides_no population
# 0   Albania  1985  female  15-24 years           0     277900
# 1   Albania  1985  female  25-34 years           0     246800
# 2   Albania  1985  female  35-54 years           0     267500
# 3   Albania  1985  female   5-14 years           0     298300
# 4   Albania  1985  female  55-74 years           0     138700
# 5   Albania  1985  female    75+ years           0      34200
# 6   Albania  1985    male  15-24 years           0     301400
# 7   Albania  1985    male  25-34 years           0     264200
# 8   Albania  1985    male  35-54 years           0     296700
# 9   Albania  1985    male   5-14 years           0     325800
# 10  Albania  1985    male  55-74 years           0     132500
# 11  Albania  1985    male    75+ years           0      21100
# 12  Albania  1986  female  15-24 years           0     283900
# 13  Albania  1986  female  25-34 years           0     252100
# ...

# %%
sns.

# %%
# sử dụng làm data.loc để lọc ra data:
# data1= (data.loc[(data['year']==1985)&(data['suicides_no'])&(data['country'].isin(['Albania','Costa Rica','Chile']))])
data1 = (data.loc[(data['year']>= 2013)&(data['country'].isin(['Malaysia','Singapore']))])
data1
# Out:
#          country  year     sex          age suicides_no population
# 24060   Malaysia  2013  female  15-24 years           0          0
# 24061   Malaysia  2013  female  25-34 years           1          0
# 24062   Malaysia  2013  female  35-54 years           2          0
# 24063   Malaysia  2013  female   5-14 years           0          0
# 24064   Malaysia  2013  female  55-74 years           2          0
# 24065   Malaysia  2013  female    75+ years           0          0
# 24066   Malaysia  2013    male  15-24 years           4          0
# 24067   Malaysia  2013    male  25-34 years           5          0
# 24068   Malaysia  2013    male  35-54 years           3          0
# 24069   Malaysia  2013    male   5-14 years           1          0
# 24070   Malaysia  2013    male  55-74 years           3          0
# 24071   Malaysia  2013    male    75+ years           1          0
# 24072   Malaysia  2014  female  15-24 years           0          0
# ...

# %%
sns.set(style="darkgrid")
sns.catplot(x='age',y='suicides_no',hue='sex',col='year',kind='bar',col_wrap=2,data=data1,aspect=1.2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.catplot(x='year',hue='sex',data=data1,kind='count',aspect=1)

# %%
data1.drop(columns='percentage')
#data1.drop(['percentage'],axis=1)
# Out:
#          country  year     sex          age suicides_no population
# 24060   Malaysia  2013  female  15-24 years           0          0
# 24061   Malaysia  2013  female  25-34 years           1          0
# 24062   Malaysia  2013  female  35-54 years           2          0
# 24063   Malaysia  2013  female   5-14 years           0          0
# 24064   Malaysia  2013  female  55-74 years           2          0
# 24065   Malaysia  2013  female    75+ years           0          0
# 24066   Malaysia  2013    male  15-24 years           4          0
# 24067   Malaysia  2013    male  25-34 years           5          0
# 24068   Malaysia  2013    male  35-54 years           3          0
# 24069   Malaysia  2013    male   5-14 years           1          0
# 24070   Malaysia  2013    male  55-74 years           3          0
# 24071   Malaysia  2013    male    75+ years           1          0
# 24072   Malaysia  2014  female  15-24 years           0          0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 24060 to 35615
# Data columns (total 7 columns):
# country        60 non-null object
# year           60 non-null int64
# sex            60 non-null object
# age            60 non-null object
# suicides_no    60 non-null object
# population     60 non-null object
# percentage     51 non-null float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 6.2+ KB

# %%
data1.drop(['percentage'],axis=1)
# Out:
#          country  year     sex          age suicides_no population
# 24060   Malaysia  2013  female  15-24 years           0          0
# 24061   Malaysia  2013  female  25-34 years           1          0
# 24062   Malaysia  2013  female  35-54 years           2          0
# 24063   Malaysia  2013  female   5-14 years           0          0
# 24064   Malaysia  2013  female  55-74 years           2          0
# 24065   Malaysia  2013  female    75+ years           0          0
# 24066   Malaysia  2013    male  15-24 years           4          0
# 24067   Malaysia  2013    male  25-34 years           5          0
# 24068   Malaysia  2013    male  35-54 years           3          0
# 24069   Malaysia  2013    male   5-14 years           1          0
# 24070   Malaysia  2013    male  55-74 years           3          0
# 24071   Malaysia  2013    male    75+ years           1          0
# 24072   Malaysia  2014  female  15-24 years           0          0
# ...

# %%
data2=(data.loc[(data['year']>=2013) & (data['country']=='Canada')])
data2
# Out:
#      country  year     sex          age suicides_no   population
# 8088  Canada  2013  female  15-24 years         138  2.26117e+06
# 8089  Canada  2013  female  25-34 years         135  2.43366e+06
# 8090  Canada  2013  female  35-54 years         400  5.00377e+06
# 8091  Canada  2013  female   5-14 years          20  1.82301e+06
# 8092  Canada  2013  female  55-74 years         255  3.88732e+06
# 8093  Canada  2013  female    75+ years          65  1.41063e+06
# 8094  Canada  2013    male  15-24 years         300  2.36281e+06
# 8095  Canada  2013    male  25-34 years         439  2.45634e+06
# 8096  Canada  2013    male  35-54 years        1244  5.03271e+06
# 8097  Canada  2013    male   5-14 years          15  1.92775e+06
# 8098  Canada  2013    male  55-74 years         812  3.72462e+06
# 8099  Canada  2013    male    75+ years         231       991048

# %%
data2.count()
# Out:
# country        12
# year           12
# sex            12
# age            12
# suicides_no    12
# population     12
# dtype: int64

# %%
data2['percent']=data2['suicides_no']/data2['year'] * 100
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43776 entries, 0 to 43775
# Data columns (total 6 columns):
# country        43776 non-null object
# year           43776 non-null int64
# sex            43776 non-null object
# age            43776 non-null object
# suicides_no    43776 non-null object
# population     43776 non-null object
# dtypes: int64(1), object(5)
# memory usage: 2.0+ MB

# %%
data2[suicides_no].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-224-4befba753b0c> in <module>
# ----> 1 data2[suicides_no].astype(int)
#
# NameError: name 'suicides_no' is not defined
